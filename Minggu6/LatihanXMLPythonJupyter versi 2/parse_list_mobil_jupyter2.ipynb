# %% [markdown]
# # Test parse_list_mobil Jupyter Notebook versi 2

# %%
import xml.dom.minidom as minidom

def main():
    
    doc = minidom.parse(r'C:\Users\Masahiro benz\Kuliah\S4\PMesin\Minggu4\LatihanXMLPythonJupyter versi 2\list_mobil.xml')

    print(doc.nodeName)
    print("Experiment XML Python")
    print("List mobil supercar, hypercar, dan luxury car")

    mobil_list = doc.getElementsByTagName("mobil")

    for i, mobil in enumerate(mobil_list):
        no = mobil.getElementsByTagName("no")[0].firstChild.data
        merek = mobil.getElementsByTagName("merek")[0].firstChild.data
        model = mobil.getElementsByTagName("model")[0].firstChild.data
        tahun = mobil.getElementsByTagName("tahun")[0].firstChild.data
        mesin = mobil.getElementsByTagName("mesin")[0].firstChild.data

        print(f"\nNo: {no}")
        print(f"Merek: {merek}")
        print(f"Model: {model}")
        print(f"Tahun: {tahun}")
        print(f"Mesin: {mesin}")

if __name__ == "__main__":
    main()
# Out:
# #document
# Experiment XML Python
# List mobil supercar, hypercar, dan luxury car
#
# No: 1.
# Merek: Audi
# Model: R8 Coupe
# Tahun: 2022
# Mesin: V10 5.2L
#
# No: 2.
# Merek: Audi
# Model: A8L 60 TFSIe
# Tahun: 2019
# Mesin: V6 3.0L Twin-turbo Plug-in Hybrid
#
# No: 3.
# Merek: Audi
# Model: S8
# Tahun: 2019
# Mesin: V8 4.0L Twin-turbo
#
# No: 4.
# Merek: BMW
# Model: M8 Coupe
# Tahun: 2020
# Mesin: V8 4.4L Twin-turbo
#
# No: 5.
# Merek: BMW
# Model: M760li
# Tahun: 2020
# Mesin: V12 6.6L Twin-turbo
#
# No: 6.
# Merek: BMW
# Model: i8
# Tahun: 2018
# Mesin: Inline 3 1.5L Turbo Plug-in Hybrid
#
# No: 7.
# Merek: Mercedes-AMG
# Model: S63 AMG Coupe
# Tahun: 2018
# Mesin: V8 4.0L Twin-turbo
#
# No: 8.
# Merek: Mercedes-AMG
# Model: S65 AMG Coupe
# Tahun: 2019
# Mesin: V12 6.0L Twin-turbo
#
# No: 9.
# Merek: Mercedes-Benz
# Model: CLK GTR
# Tahun: 1998
# Mesin: V12 6.9L
#
# No: 10.
# Merek: Porsche
# Model: 918 Spyder
# Tahun: 2015
# Mesin: V8 4.6L Plug-in Hybrid
#
# No: 11.
# Merek: Porsche
# Model: 911 GT1
# Tahun: 1997
# Mesin: Flat 6 3.2L Twin-turbo
#
# No: 12.
# Merek: Porsche
# Model: 911 GT3
# Tahun: 2022
# Mesin: Flat 6 4.0L
#
# No: 13.
# Merek: Nissan
# Model: GT-R R35 Nismo
# Tahun: 2019
# Mesin: V6 3.8L Twin-turbo
#
# No: 14.
# Merek: Nissan
# Model: Skyline GT-R R34
# Tahun: 2002
# Mesin: Inline 6 2.8L Twin-turbo
#
# No: 15.
# Merek: Nissan
# Model: Z RZ34
# Tahun: 2022
# Mesin: V6 3.0L Twin-turbo
#
# No: 16.
# Merek: Honda
# Model: NSX-R
# Tahun: 2002
# Mesin: V6 3.2L
#
# No: 17.
# Merek: Honda
# Model: Acura NSX
# Tahun: 2018
# Mesin: V6 3.5L Twin-turbo Plug-in Hybrid
#
# No: 18.
# Merek: Bentley
# Model: Mulsanne
# Tahun: 2020
# Mesin: V8 6.75L Twin-turbo
#
# No: 19.
# Merek: Bentley
# Model: Flying Spur
# Tahun: 2021
# Mesin: W12 6.0L Twin-turbo
#
# No: 20.
# Merek: Bugatti
# Model: Chiron
# Tahun: 2018
# Mesin: W16 8.0L Quad-turbo
