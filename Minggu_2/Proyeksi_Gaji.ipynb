# %%
import pandas as pd

# %%
df = pd.read_csv("Data_Gaji.csv")

# %%
df.head()
# Out:
#    Tahun Pengalaman   Gaji
# 0               1.1  39343
# 1               1.3  46205
# 2               1.5  37731
# 3               2.0  43525
# 4               2.2  39891

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Tahun Pengalaman  30 non-null     float64
#  1   Gaji              30 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 612.0 bytes

# %%
X = df.iloc[:, :-1]
y = df.iloc[:, 1]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1/3, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)

# %%
import matplotlib.pyplot as plt
plt.scatter(X_train, y_train, color="green")
plt.plot(X_train, regressor.predict(X_train), color="red")
plt.title("Tahun Pengalaman VS Gaji")
plt.xlabel("Tahun Pengalaman")
plt.ylabel("Gaji")
plt.show()

# %%
plt.scatter(X_test, y_test, color="green")
plt.plot(X_train, regressor.predict(X_train), color="red")
plt.title("Tahun Pengalaman VS Gaji")
plt.xlabel("Tahun Pengalaman")
plt.ylabel("Gaji")
plt.show()

# %%
salary_pred = regressor.predict([[10]])
print("Gaji untuk tahun pengalaman itu : ", salary_pred)
# Out:
# Gaji untuk tahun pengalaman itu :  [120275.61667525]
# C:\Users\Masahiro benz\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
